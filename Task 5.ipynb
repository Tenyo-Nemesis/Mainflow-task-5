# %%
#Main Flow
#Task 5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\Priyanshu\\Downloads\\heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.hist(bins = 50, grid = False, figsize = (20,15));

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
#Let's begin formulating queries for this dataset.

#Q.1 How many people have heart disease and how many people doesn't have heart disease ?

#getting the values
df.target.value_counts()

#plotting bar chart
df.target.value_counts().plot(kind = 'bar', color =["orchid", "salmon"])
plt.title("Heart Disease values")
plt.xlabel("1 = Heart Disease, 0 = No heart Disease")
plt.ylabel("Amount");

# %%
#plotting a pie chart
df.target.value_counts().plot(kind = 'pie', figsize = (8, 6))
plt.legend(["Disease", "No disease"]);

# %%
# '0' represents 'Female'
# '1' represents 'Male'
# SEX column part

# '0' represents 'No disease'
# '1' represents 'Disease'
# Target column part

# Now let's check how many 'Male' and 'Female' are in the dataset
df.sex.value_counts()

# Plotting a pie chart
df.sex.value_counts().plot(kind='pie', figsize=(8, 6))
plt.title('Male Female ratio')
plt.legend(['Male', 'Female']);

# %%
#Q2. People of which sex has the most heart disease?
pd.crosstab(df.target, df.sex)
# Out:
# sex       0    1
# target
# 0        86  413
# 1       226  300

# %%
sns.countplot(x = 'target', data = df, hue ='sex')
plt.title('Heart Disease Frequency for Sex')
plt.xlabel('0 = No heart Disease, 1 = Heart Disease');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sns.countplot(x = 'target', data = df, hue ='sex')
#       2 plt.title('Heart Disease Frequency for Sex')
#       3 plt.xlabel('0 = No heart Disease, 1 = Heart Disease')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
# Number of male is more than double in our dataset than female.
# More than 45% male has heart disease and 75% female has heart disease.

# %%
# Q3. People of which sex has which type of chest pain most?

# Counting values for different chest pain
df.cp.value_counts()
# Out:
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %%
# Plotting a bar chart
df.cp.value_counts().plot(kind='bar', color=['salmon', 'lightskyblue', 'springgreen', 'khaki'])
plt.title('Chest pain type count');

# %%
pd.crosstab(df.sex, df.cp)
# Out:
# cp     0    1    2   3
# sex
# 0    133   57  109  13
# 1    364  110  175  64

# %%
pd.crosstab(df.sex, df.cp).plot(kind='bar', color=['coral', 'lightskyblue', 'plum', 'khaki'])
plt.title('Type of chest pain for sex')
plt.xlabel('0 = Female, 1 = Male');

# %%
# Now question 4!

# Q4. People with which chest pain are most prone to have heart disease?
pd.crosstab(df.cp, df.target)

sns.countplot(x='cp', data=df, hue='target');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 6
#       1 # Now question 4!
#       2
#       3 # Q4. People with which chest pain are most prone to have heart disease?
#       4 pd.crosstab(df.cp, df.target)
# ----> 6 sns.countplot(x='cp', data=df, hue='target')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
# Most of the people who has 'type 0' chest pain has less chance of heart disease.
# And we see the opposite for other types.

# Now let's take a look at our age column.
# Create a distribution plot with normal distribution curve
sns.displot(x='age', data=df, bins=30, kde=True);
# Out:
# C:\Users\Priyanshu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# '58-59' year old people are most in the dataset.

# Let's plot another distribution plot for 'Maximum heart rate'
sns.displot(x='thalach', data=df, bins=30, kde=True, color='chocolate');
# Out:
# C:\Users\Priyanshu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# From this plot we get a clear overview about Maximum heart rate represented by 'thalach'

# %%
#Additional Questions with Answers

#Q5. What is the distribution of cholesterol levels in the dataset?

# Plotting the distribution of cholesterol levels
sns.displot(x='chol', data=df, bins=30, kde=True, color='purple');
plt.title('Cholesterol Level Distribution');
# Out:
# C:\Users\Priyanshu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Q6. How does age affect the presence of heart disease?

# Creating a boxplot to analyze the distribution of age for each target class
sns.boxplot(x='target', y='age', data=df);
plt.title('Age vs Heart Disease');
plt.xlabel('0 = No Heart Disease, 1 = Heart Disease');

# %%
#Q7. Is there any correlation between maximum heart rate achieved ('thalach') and cholesterol levels ('chol')?

# Creating a scatter plot to examine the correlation between 'thalach' and 'chol'
sns.scatterplot(x='thalach', y='chol', data=df, hue='target', palette='coolwarm');
plt.title('Correlation between Thalach and Cholesterol Levels');
plt.xlabel('Maximum Heart Rate Achieved (thalach)');
plt.ylabel('Cholesterol Level (chol)');
